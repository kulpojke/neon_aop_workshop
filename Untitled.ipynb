# %%
import rpy2
import rpy2.robjects.packages as rpackages
base = importr('base')
# import R's utility package
utils = rpackages.importr('utils')
# select a mirror for R packages
utils.chooseCRANmirror(ind=1) # select the first mirror in the list

# R package names
packnames = ('devtools', 'neonUtilities', 'rgdal')

# R vector of strings
from rpy2.robjects.vectors import StrVector

# Selectively install what needs to be install.
names_to_install = [x for x in packnames if not rpackages.isinstalled(x)]
if len(names_to_install) > 0:
    utils.install_packages(StrVector(names_to_install))


neonUtilities = importr('neonUtilities')
#geoNEON = importr('geoNEON')
# Out:
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/rgdal_1.5-18.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 4388549 bytes (4.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 4.2 MB
#
#
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/tmp/RtmpxwR6Pd/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Updating HTML index of packages in '.Library'
#
# R[write to console]: Making 'packages.html' ...
# R[write to console]:  done

# %%
rpy2.robjects.r('devtools::install_github("NEONScience/NEON-geolocation/geoNEON")')
# Out:
# R[write to console]: Downloading GitHub repo NEONScience/NEON-geolocation@HEAD
#
# R[write to console]: Installing 1 packages: rgdal
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/rgdal_1.5-18.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 4388549 bytes (4.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 4.2 MB
#
#
# R[write to console]: Error: Failed to install 'geoNEON' from GitHub:
#   (converted from warning) installation of package ‘rgdal’ had non-zero exit status
#
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: In (function (pkgs, lib, repos = getOption("repos"), contriburl = contrib.url(repos,  :
# R[write to console]:
#
# R[write to console]:  installation of package ‘rgdal’ had non-zero exit status
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-16-0adf5ac90c27> in <module>
# ----> 1 rpy2.robjects.r('devtools::install_github("NEONScience/NEON-geolocation/geoNEON")')
#
# /opt/conda/lib/python3.8/site-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     414     def __call__(self, string):
#     415         p = rinterface.parse(string)
# --> 416         res = self.eval(p)
#     417         return conversion.rpy2py(res)
#     418
#
# /opt/conda/lib/python3.8/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     195                 v = kwargs.pop(k)
#     196                 kwargs[r_k] = v
# --> 197         return (super(SignatureTranslatedFunction, self)
#     198                 .__call__(*args, **kwargs))
#     199
#
# /opt/conda/lib/python3.8/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     123             else:
#     124                 new_kwargs[k] = conversion.py2rpy(v)
# --> 125         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     126         res = conversion.rpy2py(res)
#     127         return res
#
# /opt/conda/lib/python3.8/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      42 def _cdata_res_to_rinterface(function):
#      43     def _(*args, **kwargs):
# ---> 44         cdata = function(*args, **kwargs)
#      45         # TODO: test cdata is of the expected CType
#      46         return _cdata_to_rinterface(cdata)
#
# /opt/conda/lib/python3.8/site-packages/rpy2/rinterface.py in __call__(self, *args, **kwargs)
#     622                     error_occured))
#     623             if error_occured[0]:
# --> 624                 raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     625         return res
#     626
#
# RRuntimeError: Error: Failed to install 'geoNEON' from GitHub:
#   (converted from warning) installation of package ‘rgdal’ had non-zero exit status

# %%
rpy2.robjects.r('?symbols')
# Out:
# R object with classes: ('help_files_with_topic',) mapped to:
# ['/opt/conda/lib/R/library/graphics/help/symbols']
